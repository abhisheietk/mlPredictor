# %%
from ipywidgets import interactive, widgets
from datetime import datetime, timedelta


year = widgets.Dropdown(options={2014, 2015, 2016, 2017, 2018, 2019, 2020},
                         value=2016,
                         description='Year:',
                        )

month = widgets.Dropdown(options={'January'  : 1,  # 31 days
                                   'February' : 2,  # 28 days in a common year and 29 days in leap years
                                   'March'    : 3,  # 31 days
                                   'April'    : 4,  # 30 days
                                   'May'      : 5,  # 31 days
                                   'June'     : 6,  # 30 days
                                   'July'     : 7,  # 31 days
                                   'August'   : 8,  # 31 days
                                   'September': 9,  # 30 days
                                   'October'  : 10, # 31 days
                                   'November' : 11, # 30 days
                                   'December' : 12, # 31 
                                  },
                          value=1,
                          description='Month:',
                         )

day = widgets.IntRangeSlider(value=[5, 7],
                              min=1,
                              max=60,
                              step=1,
                              description='Day Range:',
                              disabled=False,
                              continuous_update=False,
                              orientation='horizontal',
                              readout=True,
                              readout_format='d',
                             )

distance = widgets.IntRangeSlider(value=[0, 1000],
                              min=0,
                              max=3000,
                              step=1,
                              description='Distance:',
                              disabled=False,
                              continuous_update=False,
                              orientation='horizontal',
                              readout=True,
                              readout_format='d',
                             )

site = widgets.Dropdown(options=['Aggarwal College Ballabgarh', 'Gauhati University',
                                      'GZRSC, Aizawl', 'IIG Vizag', 'IOP Bhubaneshwar',
                                      'Kashmir University', 'Manipur University', 'Mizoram University',
                                      'Nagaland University', 'NEHU Shillong', 'NIT Rourkela',
                                      'SGRC Shillong', 'Silchar Assam', 'SINP Kolkata', 'IIT Roorkee'],
                             #value='pineapple',
                             description='Sellect Sites:',
                             disabled=False
                            )



def getDateTime(year, month, day, distance, site):
    m = datetime(year=year, month=month, day=1)
    start = m + timedelta(days=day[0]-1)
    stop  = m + timedelta(days=day[1]-1)
    print(start)
    print(stop)
    print(distance[0])
    print(distance[1])
    return start, stop

#w = interactive(getDateTime, year=year, month=month, day=day, distance=distance, site=site)
#display(w)
